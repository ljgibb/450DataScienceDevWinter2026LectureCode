# %% [markdown]
# # .ipynb Jupyter Notebooks
#
# ## Learning Goals
# - Explore key Jupyter Notebook features
# - Evaluate when to use a Jupyter Notebook versus a basic `.py` file
# - Run code inside a notebook

# %% [markdown]
# >Note: Be sure to open VS Code using Anaconda so your environment is already set up.

# %% [markdown]
# ### The Difference Between `.ipynb` and `.py`
# So far, you have probably been using `.py` files to run Python scripts. This is the default file type for Python and is useful for a wide range of tasks, from building web scrapers to creating backend APIs. For many software solutions, `.py` files are exactly what you want.
#
# However, in the world of data science, there is another common file type: `.ipynb`.
#
# `.ipynb` files are primarily used for Jupyter Notebooks. The name originally comes from **IPython Notebook**, which is where the file extension comes from. Today, when we talk about `.ipynb` files, we are generally referring to Jupyter Notebooks.

# %% [markdown]
# ### Why Not Just Use `.py`?
# `.ipynb` files are especially well suited for data analysis and machine learning work. Notebooks combine easy to read Markdown text cells, like this one, with executable code cells.
#
# Traditional Python projects are often larger and structured across multiple modules and files. Jupyter Notebooks, on the other hand, are better suited for experimentation, exploration, and explaining your thought process alongside your code.

# %% [markdown]
# ### When not to use Notebooks
# Jupyter notebooks are powerful tools, but they are not well suited for building fully functioning software. You will use notebooks primarily for exploration, experimentation, and research when working with ML, DL, and neural network solutions. Production systems are typically refactored into structured Python modules and packages.

# %% [markdown]
# ### Markdown Syntax
# ```
# **Bold**
# *Italic*
# ~~Strikethrough~~
# `Inline code`
# # H1
# ## H2
# ### H3
# #### H4
# - Item
# - Item
#   - Sub-item
#
# 1. First
# 2. Second
# 3. Third
#
# [Link text](https://example.com)
# ![Alt text](image.png)
# ```
#
# Your Turn: In a Markdown cell, add an H1 with your name, list your hobbies, include an image, and show one line of inline code.

# %% [markdown]
# # Leah Gibbons
#
# ## Hobbies
#
# * Reading
# * Memorizing poetry
#     * Poe
#     * Frost
#     * Tolkien
#     * Khayyam/Fitzgerald
#     * Donne
#     * Blake
# * Chanting prime factorizations of numbers
# * Replaying Planescape Torment
#
# ![Santa Marx](images/Karl_Marx_Santa.png)
#
# `while 1 == 0:`

# %% [markdown]
# ### Cells
# You have already run quite a bit of code in this week’s assignment, but let’s go over it once more.
#
# - **Text cells** can be created using the `+ Markdown` button
# - **Code cells** can be created using the `+ Code` button
# - Both buttons appear when you hover near the bottom of the previous cell
# - The third button is **Generate**, but we will not be using that this quarter. It is important to learn the basics first, so consider it off limits for now.
#
# Now, create a **code cell** that prints out a greeting.
# Run the cell using the **play button** on the left side of the cell or top right of the cell.

# %% [markdown]
# Look at that output, it's right under the cell. If you've been coding for a while in other languages you'll know that we typically need a console of some kind to typically see an output like that, but with notebooks the output is in the same file.
#
# Lets go through some more buttons.
#
# ![Toolbar example](images/run_widget.png)
# From left to right
# - Run cell
#   - runs the single cell
# - Run and next
#   - runs the cell but moves us on to the next cell
# - Toggle output
#   - Shows/Hides the output
# - More
#   - More actions around the cell funciton, such as joining
# - Delete Cell
#
# ![Toolbar example](images/top_bar.png)
# - Generate (ignore for now)
# - New Code Cell
# - New Text Cell
# - Run All
#   - Runs every cell
# - Restart
#   - Restarts the notebook, clearing the variables, imports or anything in memory
# - Clear all outputs
# - Jupyter Variables
#   - Shows all varaibles
# - Outline
# - More

# %% [markdown]
# ### Loading Data

# %% [markdown]
# ### Numpy Preview
# NumPy is a Python library that converts standard Python lists into array objects. These arrays are faster, more memory-efficient, and provide many additional mathematical and numerical operations compared to built-in Python lists.

# %%
import numpy as np
arr_with_range = np.arange(8, 97, 13)
print(arr_with_range)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy as np
#       2 arr_with_range = np.arange(8, 97, 13)
#       3 print(arr_with_range)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
num_array = np.array([1, 2, 3, 4, 5])
print(num_array.shape)
print(num_array.dtype)
